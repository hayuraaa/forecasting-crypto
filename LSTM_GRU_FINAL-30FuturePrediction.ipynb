# %% [markdown]
# #**Import Libraries and Download Data**

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import math
from warnings import simplefilter
from hyperopt import fmin, tpe, hp, space_eval, Trials
from tensorflow.keras.callbacks import EarlyStopping
import plotly.graph_objects as go

# Mute sklearn warnings
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Download stock price data
data = yf.download("STX4847-USD", start="2022-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2022-01-01  2.167764  2.283409  2.165467  2.283105   2.283105   48609123
# 2022-01-02  2.283221  2.402877  2.283007  2.391267   2.391267  114675175
# 2022-01-03  2.391378  2.391831  2.237839  2.297845   2.297845   78640545
# 2022-01-04  2.296836  2.401285  2.268533  2.348068   2.348068   98281069
# 2022-01-05  2.352790  2.460170  2.114055  2.244129   2.244129  166361376
# ...              ...       ...       ...       ...        ...        ...
# 2023-12-27  1.628866  1.734575  1.533403  1.561880   1.561880  244507782
# 2023-12-28  1.564280  1.593884  1.400003  1.474471   1.474471  184274692
# 2023-12-29  1.473594  1.545630  1.406771  1.429965   1.429965  178436613
# 2023-12-30  1.430054  1.470070  1.373246  1.421242   1.421242  121511853
# 2023-12-31  1.421071  1.530167  1.394727  1.503445   1.503445  129694052
#
# [730 rows x 6 columns]

# %%
print(data.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
print(data.shape)
# Out:
# (730, 6)

# %%
data.iloc[:, 0:-2].describe()
# Out:
#              Open        High         Low       Close
# count  730.000000  730.000000  730.000000  730.000000
# mean     0.695633    0.725877    0.667226    0.694669
# std      0.437020    0.458000    0.414400    0.434633
# min      0.206817    0.212052    0.200486    0.206867
# 25%      0.380476    0.391136    0.361440    0.378746
# 50%      0.584219    0.602711    0.559857    0.584214
# 75%      0.876010    0.914137    0.839570    0.873982
# max      2.391378    2.636223    2.283007    2.391267

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 730 entries, 2022-01-01 to 2023-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       730 non-null    float64
#  1   High       730 non-null    float64
#  2   Low        730 non-null    float64
#  3   Close      730 non-null    float64
#  4   Adj Close  730 non-null    float64
#  5   Volume     730 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 39.9 KB

# %%
#Normalisasi Data : Min-Max Scaler

close_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(close_prices)

# %%
# Extract original and scaled close prices
original_close_prices = data['Close'].values
scaled_close_prices = scaled_data.flatten()

# Calculate statistics
original_stats = pd.Series(original_close_prices).describe()
scaled_stats = pd.Series(scaled_close_prices).describe()

# Print the summary
print("Original Close Prices Statistics:")
print(original_stats)

print("\nScaled Close Prices Statistics:")
print(scaled_stats)
# Out:
# Original Close Prices Statistics:
# count    730.000000
# mean       0.694669
# std        0.434633
# min        0.206867
# 25%        0.378746
# 50%        0.584214
# 75%        0.873982
# max        2.391267
# dtype: float64
#
# Scaled Close Prices Statistics:
# count    730.000000
# mean       0.223312
# std        0.198971
# min        0.000000
# 25%        0.078685
# 50%        0.172746
# 75%        0.305400
# max        1.000000
# dtype: float64

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Plot all prices
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data['Open'], mode='lines', name='Opening Price', line=dict(color='red')))
fig.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='Closing Price', line=dict(color='green')))
fig.add_trace(go.Scatter(x=data.index, y=data['Low'], mode='lines', name='Low Price', line=dict(color='black')))
fig.add_trace(go.Scatter(x=data.index, y=data['High'], mode='lines', name='High Price', line=dict(color='blue')))

fig.update_layout(
    title='Stock Price History',
    xaxis=dict(title='Date'),
    yaxis=dict(title='Stock Price'),
    legend=dict(x=0, y=1, traceorder='normal', orientation='h'),
)

# Plot subplots for each individual price
fig_subplots = make_subplots(rows=2, cols=2, subplot_titles=('Opening Price', 'Closing Price', 'Low Price', 'High Price'))

fig_subplots.add_trace(go.Scatter(x=data.index, y=data['Open'], mode='lines', name='Opening Price', line=dict(color='red')), row=1, col=1)
fig_subplots.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='Closing Price', line=dict(color='green')), row=1, col=2)
fig_subplots.add_trace(go.Scatter(x=data.index, y=data['Low'], mode='lines', name='Low Price', line=dict(color='black')), row=2, col=1)
fig_subplots.add_trace(go.Scatter(x=data.index, y=data['High'], mode='lines', name='High Price', line=dict(color='blue')), row=2, col=2)

fig_subplots.update_layout(title='Stock Price Subplots', showlegend=False)

fig.show()
fig_subplots.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ad4c6422-c8e8-4bac-a924-a2c6ee206c32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad4c6422-c8e8-4bac-a924-a2c6ee206c32")) {                    Plotly.newPlot(                        "ad4c6422-c8e8-4bac-a924-a2c6ee206c32",                        [{"line":{"color":"red"},"mode":"lines","name":"Opening Price","x":["2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-28T00:00:00","2022-05-29T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","20 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="58742a3c-2fad-4fc1-be22-2b0899778cca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58742a3c-2fad-4fc1-be22-2b0899778cca")) {                    Plotly.newPlot(                        "58742a3c-2fad-4fc1-be22-2b0899778cca",                        [{"line":{"color":"red"},"mode":"lines","name":"Opening Price","x":["2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-28T00:00:00","2022-05-29T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","20 ...

# %% [markdown]
# #**Data Preprocessing and Preparation**

# %%
# Data preparation
def prepare_data(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        lag_values = data[i:(i + n_steps), 0]
        X.append(np.concatenate([lag_values, [data[i + n_steps, 0]]]))
        y.append(data[i + n_steps, 0])
    return np.array(X), np.array(y)

n_steps = 120
X, y = prepare_data(scaled_data, n_steps)

# Splitting into train and test sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape data for LSTM and GRU models
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
X_train_gru = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_gru = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# #**Hyperparameter Tuning**

# %%
# Define hyperparameter search space
space = {
    'units': hp.choice('units', [50, 100, 150]),
    'dropout_rate': hp.uniform('dropout_rate', 0.2, 0.5),
    'learning_rate': hp.loguniform('learning rate', np.log(0.001), np.log(0.01)),
    'epochs': hp.choice('epochs', [50, 100, 150]),
    'batch_size': hp.choice('batch_size', [32, 64, 128])
}

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %% [markdown]
# #**Model Building and Training**

# %%
LSTM

# %%
# Create a function to build and train the model with hyperparameters
from tensorflow.keras.optimizers import Adamax

def objective(params, model_type, X_train, y_train, X_test, y_test):
    model = Sequential()
    if model_type == 'lstm':
        model.add(LSTM(units=params['units'], return_sequences=True, activation='tanh', input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(params['dropout_rate']))
        model.add(LSTM(units=params['units'], return_sequences=True, activation='tanh'))
        model.add(Dropout(params['dropout_rate']))
        model.add(LSTM(units=params['units'], activation='tanh'))
        model.add(Dense(units=1))
    elif model_type == 'gru':
        model.add(GRU(units=params['units'], return_sequences=True, activation='tanh', input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(params['dropout_rate']))
        model.add(GRU(units=params['units'], return_sequences=True, activation='tanh'))
        model.add(Dropout(params['dropout_rate']))
        model.add(GRU(units=params['units'], activation='tanh'))
        model.add(Dense(units=1))

    model.compile(optimizer=Adamax(learning_rate=params['learning_rate']), loss='mean_squared_error')

    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'],
                        validation_split=0.1, callbacks=[early_stopping], verbose=0)

    y_pred = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred)
    y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

    mse = mean_squared_error(y_test_orig, y_pred)
    return mse, history

# Set up the Trials object to keep track of the optimization process
trials_lstm = Trials()
trials_gru = Trials()

# Use the fmin function for Bayesian optimization for LSTM and GRU
best_lstm = fmin(fn=lambda params: objective(params, 'lstm', X_train_lstm, y_train, X_test_lstm, y_test)[0],
                 space=space, algo=tpe.suggest, max_evals=20, trials=trials_lstm)

best_gru = fmin(fn=lambda params: objective(params, 'gru', X_train_gru, y_train, X_test_gru, y_test)[0],
                space=space, algo=tpe.suggest, max_evals=20, trials=trials_gru)

# Get the best hyperparameters from the optimization results
best_params_lstm = space_eval(space, best_lstm)
best_params_gru = space_eval(space, best_gru)
# Out:
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 14ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 4s
# 4/4 [==============================] - 1s 15ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 14ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 14ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 4s
# 4/4 [==============================] - 1s 15ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 5s
# 4/4 [==============================] - ETA: 0s
# 4/4 [==============================] - 2s 20ms/step
#
# 100%|██████████| 20/20 [06:00<00:00, 18.01s/trial, best loss: 0.0023282597327108287]
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 3s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 4s
# 4/4 [==============================] - 2s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 14ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 15ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 15ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 9ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 13ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 12ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 10ms/step
#
# 1/4 [======>.......................] - ETA: 2s
# 4/4 [==============================] - 1s 11ms/step
#
# 100%|██████████| 20/20 [09:18<00:00, 27.91s/trial, best loss: 4.305028980792138e-05]

# %% [markdown]
# #**Final Model and History Plot**

# %%
# Build the final LSTM model using the best hyperparameters
final_model_lstm = Sequential([
    LSTM(units=best_params_lstm['units'], return_sequences=True, input_shape=(X_train_lstm.shape[1], 1)),
    Dropout(best_params_lstm['dropout_rate']),
    LSTM(units=best_params_lstm['units'], return_sequences=True),
    Dropout(best_params_lstm['dropout_rate']),
    LSTM(units=best_params_lstm['units']),
    Dense(units=1)
])

final_model_lstm.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_params_lstm['learning_rate']),
                         loss='mean_squared_error')

# Train the final LSTM model
history_lstm = final_model_lstm.fit(X_train_lstm, y_train, epochs=best_params_lstm['epochs'],
                                    batch_size=best_params_lstm['batch_size'], verbose=2,
                                    validation_split=0.1, callbacks=[early_stopping])

# Build the final GRU model using the best hyperparameters
final_model_gru = Sequential([
    GRU(units=best_params_gru['units'], return_sequences=True, input_shape=(X_train_gru.shape[1], 1)),
    Dropout(best_params_gru['dropout_rate']),
    GRU(units=best_params_gru['units'], return_sequences=True),
    Dropout(best_params_gru['dropout_rate']),
    GRU(units=best_params_gru['units']),
    Dense(units=1)
])

final_model_gru.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_params_gru['learning_rate']),
                        loss='mean_squared_error')

# Train the final GRU model
history_gru = final_model_gru.fit(X_train_gru, y_train, epochs=best_params_gru['epochs'],
                                  batch_size=best_params_gru['batch_size'], verbose=2,
                                  validation_data=(X_test_gru, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 7/7 - 6s - loss: 0.0157 - val_loss: 0.0044 - 6s/epoch - 881ms/step
# Epoch 2/100
# 7/7 - 0s - loss: 0.0077 - val_loss: 0.0014 - 177ms/epoch - 25ms/step
# Epoch 3/100
# 7/7 - 0s - loss: 0.0034 - val_loss: 2.1043e-04 - 142ms/epoch - 20ms/step
# Epoch 4/100
# 7/7 - 0s - loss: 0.0024 - val_loss: 2.3685e-04 - 130ms/epoch - 19ms/step
# Epoch 5/100
# 7/7 - 0s - loss: 0.0019 - val_loss: 8.3813e-04 - 137ms/epoch - 20ms/step
# Epoch 6/100
# 7/7 - 0s - loss: 0.0021 - val_loss: 5.5912e-04 - 132ms/epoch - 19ms/step
# Epoch 7/100
# 7/7 - 0s - loss: 0.0017 - val_loss: 1.6346e-04 - 137ms/epoch - 20ms/step
# Epoch 8/100
# 7/7 - 0s - loss: 0.0013 - val_loss: 2.0774e-04 - 135ms/epoch - 19ms/step
# Epoch 9/100
# 7/7 - 0s - loss: 0.0013 - val_loss: 2.2585e-04 - 136ms/epoch - 19ms/step
# Epoch 10/100
# 7/7 - 0s - loss: 0.0011 - val_loss: 1.4062e-04 - 149ms/epoch - 21ms/step
# Epoch 11/100
# 7/7 - 0s - loss: 0.0011 - val_loss: 6.3213e-04 - 154ms/epoch - 22ms/step
# Epoch 12/100
# 7/7 - 0s - loss: 0.0010 - val_loss: 4.1802e-04 - 211ms/epoch - 30ms/step
# Epoch 13/100
# 7/7 - 0s - loss: 0.0011 - val_loss: 1.8196e-04 - 179ms/epoch - 26ms/step
# Epoch 14/100
# 7/7 - 0s - loss: 9.4391e-04 - val_loss: 1.1221e-04 - 180ms/epoch - 26ms/step
# Epoch 15/100
# 7/7 - 0s - loss: 7.9354e-04 - val_loss: 1.5678e-04 - 189ms/epoch - 27ms/step
# Epoch 16/100
# 7/7 - 0s - loss: 7.4288e-04 - val_loss: 9.7758e-05 - 184ms/epoch - 26ms/step
# Epoch 17/100
# 7/7 - 0s - loss: 7.3807e-04 - val_loss: 1.3323e-04 - 181ms/epoch - 26ms/step
# Epoch 18/100
# 7/7 - 0s - loss: 6.3498e-04 - val_loss: 2.0681e-04 - 190ms/epoch - 27ms/step
# Epoch 19/100
# 7/7 - 0s - loss: 6.5983e-04 - val_loss: 1.4735e-04 - 198ms/epoch - 28ms/step
# Epoch 20/100
# 7/7 - 0s - loss: 6.8716e-04 - val_loss: 2.6674e-04 - 202ms/epoch - 29ms/step
# Epoch 21/100
# 7/7 - 0s - loss: 5.7582e-04 - val_loss: 1.3449e-04 - 186ms/epoch - 27ms/step
# Epoch 22/100
# 7/7 - 0s - loss: 6.0435e-04 - val_loss: 1.2608e-04 - 137ms/epoch - 20ms/step
# Epoch 23/100
# 7/7 - 0s - loss: 5.5050e-04 - val_loss: 9.4058e-05 - 143ms/epoch - 20ms/step
# Epoch 24/100
# 7/7 - 0s - loss: 5.5025e-04 - val_loss: 7.7981e-05 - 135ms/epoch - 19ms/step
# Epoch 25/100
# 7/7 - 0s - loss: 5.4218e-04 - val_loss: 8.2748e-05 - 132ms/epoch - 19ms/step
# Epoch 26/100
# 7/7 - 0s - loss: 4.8580e-04 - val_loss: 1.6984e-04 - 131ms/epoch - 19ms/step
# Epoch 27/100
# 7/7 - 0s - loss: 5.5626e-04 - val_loss: 8.1472e-05 - 136ms/epoch - 19ms/step
# Epoch 28/100
# 7/7 - 0s - loss: 5.7006e-04 - val_loss: 7.7517e-05 - 137ms/epoch - 20ms/step
# Epoch 29/100
# 7/7 - 0s - loss: 5.2214e-04 - val_loss: 1.3639e-04 - 135ms/epoch - 19ms/step
# Epoch 30/100
# 7/7 - 0s - loss: 4.7835e-04 - val_loss: 1.3538e-04 - 132ms/epoch - 19ms/step
# Epoch 31/100
# 7/7 - 0s - loss: 4.8397e-04 - val_loss: 1.7701e-04 - 149ms/epoch - 21ms/step
# Epoch 32/100
# 7/7 - 0s - loss: 5.0867e-04 - val_loss: 1.2863e-04 - 131ms/epoch - 19ms/step
# Epoch 33/100
# 7/7 - 0s - loss: 4.4999e-04 - val_loss: 1.3743e-04 - 135ms/epoch - 19ms/step
# Epoch 34/100
# 7/7 - 0s - loss: 4.3575e-04 - val_loss: 7.3665e-05 - 139ms/epoch - 20ms/step
# Epoch 35/100
# 7/7 - 0s - loss: 3.9510e-04 - val_loss: 6.4931e-05 - 143ms/epoch - 20ms/step
# Epoch 36/100
# 7/7 - 0s - loss: 3.7259e-04 - val_loss: 7.7945e-05 - 135ms/epoch - 19ms/step
# Epoch 37/100
# 7/7 - 0s - loss: 4.4877e-04 - val_loss: 6.6276e-05 - 131ms/epoch - 19ms/step
# Epoch 38/100
# 7/7 - 0s - loss: 4.1785e-04 - val_loss: 8.4717e-05 - 143ms/epoch - 20ms/step
# Epoch 39/100
# 7/7 - 0s - loss: 3.8374e-04 - val_loss: 5.8800e-05 - 138ms/epoch - 20ms/step
# Epoch 40/100
# 7/7 - 0s - loss: 3.8490e-04 - val_loss: 6.6805e-05 - 144ms/epoch - 21ms/step
# Epoch 41/100
# 7/7 - 0s - loss: 3.3807e-04 - val_loss: 6.8047e-05 - 136ms/epoch - 19ms/step
# Epoch 42/100
# 7/7 - 0s - loss: 4.5473e-04 - val_loss: 1.3568e-04 - 136ms/epoch - 19ms/step
# Epoch 43/100
# 7/7 - 0s - loss: 3.0425e-04 - val_loss: 1.4448e-04 - 140ms/epoch - 20ms/step
# Epoch 44/100
# 7/7 - 0s - loss: 4.0990e-04 - val_loss: 5.2525e-05 - 134ms/epoch - 19ms/step
# Epoch 45/100
# 7/7 - 0s - loss: 3.0660e-04 - val_loss: 6.8332e-05 - 143ms/epoch - 20ms/step
# Epoch 46/100
# 7/7 - 0s - loss: 3.1336e-04 - val_loss: 7.1483e-05 - 135ms/epoch - 19ms/step
# Epoch 47/100
# 7/7 - 0s - loss: 3.1558e-04 - val_loss: 4.8180e-05 - 144ms/epoch - 21ms/step
# Epoch 48/100
# 7/7 - 0s - loss: 3.4592e-04 - val_loss: 7.8949e-05 - 138ms/epoch - 20ms/step
# Epoch 49/100
# 7/7 - 0s - loss: 3.2184e-04 - val_loss: 4.9388e-05 - 134ms/epoch - 19ms/step
# Epoch 50/100
# 7/7 - 0s - loss: 2.9475e-04 - val_loss: 4.6452e-05 - 140ms/epoch - 20ms/step
# Epoch 51/100
# 7/7 - 0s - loss: 3.3586e-04 - val_loss: 8.9470e-05 - 136ms/epoch - 19ms/step
# Epoch 52/100
# 7/7 - 0s - loss: 2.9794e-04 - val_loss: 5.0592e-05 - 139ms/epoch - 20ms/step
# Epoch 53/100
# 7/7 - 0s - loss: 2.8616e-04 - val_loss: 4.2410e-05 - 136ms/epoch - 19ms/step
# Epoch 54/100
# 7/7 - 0s - loss: 2.7897e-04 - val_loss: 5.4679e-05 - 134ms/epoch - 19ms/step
# Epoch 55/100
# 7/7 - 0s - loss: 2.9788e-04 - val_loss: 9.8426e-05 - 124ms/epoch - 18ms/step
# Epoch 56/100
# 7/7 - 0s - loss: 2.9584e-04 - val_loss: 6.7967e-05 - 135ms/epoch - 19ms/step
# Epoch 57/100
# 7/7 - 0s - loss: 2.7774e-04 - val_loss: 4.6755e-05 - 133ms/epoch - 19ms/step
# Epoch 58/100
# 7/7 - 0s - loss: 3.3370e-04 - val_loss: 7.5190e-05 - 128ms/epoch - 18ms/step
# Epoch 59/100
# 7/7 - 0s - loss: 3.4776e-04 - val_loss: 1.0134e-04 - 126ms/epoch - 18ms/step
# Epoch 60/100
# 7/7 - 0s - loss: 2.9839e-04 - val_loss: 1.3014e-04 - 138ms/epoch - 20ms/step
# Epoch 61/100
# 7/7 - 0s - loss: 2.8608e-04 - val_loss: 6.7786e-05 - 126ms/epoch - 18ms/step
# Epoch 62/100
# 7/7 - 0s - loss: 2.8395e-04 - val_loss: 3.0580e-05 - 135ms/epoch - 19ms/step
# Epoch 63/100
# 7/7 - 0s - loss: 2.8300e-04 - val_loss: 3.0680e-05 - 141ms/epoch - 20ms/step
# Epoch 64/100
# 7/7 - 0s - loss: 3.3725e-04 - val_loss: 1.1727e-04 - 133ms/epoch - 19ms/step
# Epoch 65/100
# 7/7 - 0s - loss: 3.9192e-04 - val_loss: 2.1115e-04 - 133ms/epoch - 19ms/step
# Epoch 66/100
# 7/7 - 0s - loss: 2.9543e-04 - val_loss: 1.6329e-04 - 125ms/epoch - 18ms/step
# Epoch 67/100
# 7/7 - 0s - loss: 3.0255e-04 - val_loss: 1.7253e-04 - 133ms/epoch - 19ms/step
# Epoch 68/100
# 7/7 - 0s - loss: 2.5315e-04 - val_loss: 3.7773e-05 - 131ms/epoch - 19ms/step
# Epoch 69/100
# 7/7 - 0s - loss: 2.6508e-04 - val_loss: 2.6094e-05 - 138ms/epoch - 20ms/step
# Epoch 70/100
# 7/7 - 0s - loss: 2.8853e-04 - val_loss: 2.6811e-05 - 132ms/epoch - 19ms/step
# Epoch 71/100
# 7/7 - 0s - loss: 2.2113e-04 - val_loss: 8.4859e-05 - 138ms/epoch - 20ms/step
# Epoch 72/100
# 7/7 - 0s - loss: 2.2950e-04 - val_loss: 2.7779e-05 - 130ms/epoch - 19ms/step
# Epoch 73/100
# 7/7 - 0s - loss: 2.3867e-04 - val_loss: 9.9141e-05 - 128ms/epoch - 18ms/step
# Epoch 74/100
# 7/7 - 0s - loss: 2.0569e-04 - val_loss: 3.2381e-05 - 127ms/epoch - 18ms/step
# Epoch 75/100
# 7/7 - 0s - loss: 1.9265e-04 - val_loss: 2.0527e-05 - 138ms/epoch - 20ms/step
# Epoch 76/100
# 7/7 - 0s - loss: 2.0907e-04 - val_loss: 7.6339e-05 - 128ms/epoch - 18ms/step
# Epoch 77/100
# 7/7 - 0s - loss: 2.1405e-04 - val_loss: 3.2400e-05 - 138ms/epoch - 20ms/step
# Epoch 78/100
# 7/7 - 0s - loss: 2.1788e-04 - val_loss: 2.3578e-05 - 137ms/epoch - 20ms/step
# Epoch 79/100
# 7/7 - 0s - loss: 1.7421e-04 - val_loss: 1.9897e-05 - 134ms/epoch - 19ms/step
# Epoch 80/100
# 7/7 - 0s - loss: 1.9086e-04 - val_loss: 2.1790e-05 - 129ms/epoch - 18ms/step
# Epoch 81/100
# 7/7 - 0s - loss: 1.9617e-04 - val_loss: 1.5165e-05 - 129ms/epoch - 18ms/step
# Epoch 82/100
# 7/7 - 0s - loss: 2.0671e-04 - val_loss: 1.7020e-05 - 128ms/epoch - 18ms/step
# Epoch 83/100
# 7/7 - 0s - loss: 1.4408e-04 - val_loss: 1.9345e-05 - 135ms/epoch - 19ms/step
# Epoch 84/100
# 7/7 - 0s - loss: 1.9829e-04 - val_loss: 7.3822e-05 - 132ms/epoch - 19ms/step
# Epoch 85/100
# 7/7 - 0s - loss: 1.7391e-04 - val_loss: 1.3736e-05 - 135ms/epoch - 19ms/step
# Epoch 86/100
# 7/7 - 0s - loss: 1.7824e-04 - val_loss: 5.0919e-05 - 132ms/epoch - 19ms/step
# Epoch 87/100
# 7/7 - 0s - loss: 1.4829e-04 - val_loss: 1.5878e-05 - 130ms/epoch - 19ms/step
# Epoch 88/100
# 7/7 - 0s - loss: 1.7825e-04 - val_loss: 5.1531e-05 - 130ms/epoch - 19ms/step
# Epoch 89/100
# 7/7 - 0s - loss: 2.0158e-04 - val_loss: 4.6339e-05 - 129ms/epoch - 18ms/step
# Epoch 90/100
# 7/7 - 0s - loss: 2.1165e-04 - val_loss: 1.2498e-04 - 135ms/epoch - 19ms/step
# Epoch 91/100
# 7/7 - 0s - loss: 2.2996e-04 - val_loss: 6.0062e-05 - 128ms/epoch - 18ms/step
# Epoch 92/100
# 7/7 - 0s - loss: 1.9105e-04 - val_loss: 1.4831e-05 - 136ms/epoch - 19ms/step
# Epoch 93/100
# 7/7 - 0s - loss: 1.9476e-04 - val_loss: 8.0041e-05 - 129ms/epoch - 18ms/step
# Epoch 94/100
# 7/7 - 0s - loss: 1.5715e-04 - val_loss: 4.0311e-05 - 188ms/epoch - 27ms/step
# Epoch 95/100
# 7/7 - 0s - loss: 1.8531e-04 - val_loss: 1.2760e-05 - 183ms/epoch - 26ms/step
# Epoch 96/100
# 7/7 - 0s - loss: 1.4807e-04 - val_loss: 1.1138e-05 - 183ms/epoch - 26ms/step
# Epoch 97/100
# 7/7 - 0s - loss: 1.8138e-04 - val_loss: 1.8724e-05 - 195ms/epoch - 28ms/step
# Epoch 98/100
# 7/7 - 0s - loss: 1.4152e-04 - val_loss: 2.5660e-05 - 179ms/epoch - 26ms/step
# Epoch 99/100
# 7/7 - 0s - loss: 1.5812e-04 - val_loss: 9.2011e-06 - 193ms/epoch - 28ms/step
# Epoch 100/100
# 7/7 - 0s - loss: 1.5931e-04 - val_loss: 4.1712e-05 - 180ms/epoch - 26ms/step
# Epoch 1/150
# 16/16 - 6s - loss: 0.0050 - val_loss: 0.0015 - 6s/epoch - 377ms/step
# Epoch 2/150
# 16/16 - 0s - loss: 0.0015 - val_loss: 0.0035 - 375ms/epoch - 23ms/step
# Epoch 3/150
# 16/16 - 0s - loss: 8.2152e-04 - val_loss: 0.0013 - 372ms/epoch - 23ms/step
# Epoch 4/150
# 16/16 - 0s - loss: 6.0459e-04 - val_loss: 7.6296e-04 - 361ms/epoch - 23ms/step
# Epoch 5/150
# 16/16 - 0s - loss: 5.5955e-04 - val_loss: 9.7386e-04 - 393ms/epoch - 25ms/step
# Epoch 6/150
# 16/16 - 0s - loss: 4.4867e-04 - val_loss: 5.7317e-04 - 414ms/epoch - 26ms/step
# Epoch 7/150
# 16/16 - 0s - loss: 4.2289e-04 - val_loss: 7.0858e-04 - 321ms/epoch - 20ms/step
# Epoch 8/150
# 16/16 - 0s - loss: 3.5526e-04 - val_loss: 4.5926e-04 - 291ms/epoch - 18ms/step
# Epoch 9/150
# 16/16 - 0s - loss: 3.8859e-04 - val_loss: 4.4538e-04 - 267ms/epoch - 17ms/step
# Epoch 10/150
# 16/16 - 0s - loss: 4.0382e-04 - val_loss: 5.4228e-04 - 269ms/epoch - 17ms/step
# Epoch 11/150
# 16/16 - 0s - loss: 3.6728e-04 - val_loss: 4.7063e-04 - 281ms/epoch - 18ms/step
# Epoch 12/150
# 16/16 - 0s - loss: 3.2838e-04 - val_loss: 6.6570e-04 - 271ms/epoch - 17ms/step
# Epoch 13/150
# 16/16 - 0s - loss: 3.2256e-04 - val_loss: 4.8417e-04 - 266ms/epoch - 17ms/step
# Epoch 14/150
# 16/16 - 0s - loss: 2.9731e-04 - val_loss: 3.2936e-04 - 264ms/epoch - 16ms/step
# Epoch 15/150
# 16/16 - 0s - loss: 2.5257e-04 - val_loss: 5.2647e-04 - 274ms/epoch - 17ms/step
# Epoch 16/150
# 16/16 - 0s - loss: 2.3930e-04 - val_loss: 3.7337e-04 - 255ms/epoch - 16ms/step
# Epoch 17/150
# 16/16 - 0s - loss: 2.4867e-04 - val_loss: 4.7205e-04 - 260ms/epoch - 16ms/step
# Epoch 18/150
# 16/16 - 0s - loss: 2.4854e-04 - val_loss: 2.6026e-04 - 288ms/epoch - 18ms/step
# Epoch 19/150
# 16/16 - 0s - loss: 2.3229e-04 - val_loss: 2.2329e-04 - 272ms/epoch - 17ms/step
# Epoch 20/150
# 16/16 - 0s - loss: 2.3286e-04 - val_loss: 2.4856e-04 - 259ms/epoch - 16ms/step
# Epoch 21/150
# 16/16 - 0s - loss: 2.1238e-04 - val_loss: 2.7521e-04 - 267ms/epoch - 17ms/step
# Epoch 22/150
# 16/16 - 0s - loss: 1.5946e-04 - val_loss: 1.7739e-04 - 267ms/epoch - 17ms/step
# Epoch 23/150
# 16/16 - 0s - loss: 2.6429e-04 - val_loss: 2.3252e-04 - 272ms/epoch - 17ms/step
# Epoch 24/150
# 16/16 - 0s - loss: 2.0868e-04 - val_loss: 1.3600e-04 - 265ms/epoch - 17ms/step
# Epoch 25/150
# 16/16 - 0s - loss: 2.1306e-04 - val_loss: 2.1037e-04 - 265ms/epoch - 17ms/step
# Epoch 26/150
# 16/16 - 0s - loss: 2.2550e-04 - val_loss: 2.1525e-04 - 277ms/epoch - 17ms/step
# Epoch 27/150
# 16/16 - 0s - loss: 1.9554e-04 - val_loss: 1.1116e-04 - 262ms/epoch - 16ms/step
# Epoch 28/150
# 16/16 - 0s - loss: 2.4807e-04 - val_loss: 9.3992e-05 - 257ms/epoch - 16ms/step
# Epoch 29/150
# 16/16 - 0s - loss: 1.8516e-04 - val_loss: 8.6205e-05 - 274ms/epoch - 17ms/step
# Epoch 30/150
# 16/16 - 0s - loss: 1.9038e-04 - val_loss: 1.5019e-04 - 277ms/epoch - 17ms/step
# Epoch 31/150
# 16/16 - 0s - loss: 2.2923e-04 - val_loss: 2.7922e-04 - 262ms/epoch - 16ms/step
# Epoch 32/150
# 16/16 - 0s - loss: 2.1234e-04 - val_loss: 2.3058e-04 - 261ms/epoch - 16ms/step
# Epoch 33/150
# 16/16 - 0s - loss: 1.2540e-04 - val_loss: 4.0942e-04 - 266ms/epoch - 17ms/step
# Epoch 34/150
# 16/16 - 0s - loss: 1.5868e-04 - val_loss: 4.4072e-04 - 267ms/epoch - 17ms/step
# Epoch 35/150
# 16/16 - 0s - loss: 1.8243e-04 - val_loss: 4.5272e-04 - 264ms/epoch - 17ms/step
# Epoch 36/150
# 16/16 - 0s - loss: 1.5025e-04 - val_loss: 3.2711e-05 - 271ms/epoch - 17ms/step
# Epoch 37/150
# 16/16 - 0s - loss: 1.3490e-04 - val_loss: 2.0044e-04 - 275ms/epoch - 17ms/step
# Epoch 38/150
# 16/16 - 0s - loss: 1.4166e-04 - val_loss: 9.4829e-05 - 270ms/epoch - 17ms/step
# Epoch 39/150
# 16/16 - 0s - loss: 1.4208e-04 - val_loss: 7.6551e-05 - 256ms/epoch - 16ms/step
# Epoch 40/150
# 16/16 - 0s - loss: 1.2960e-04 - val_loss: 9.0201e-05 - 261ms/epoch - 16ms/step
# Epoch 41/150
# 16/16 - 0s - loss: 1.2707e-04 - val_loss: 7.0181e-05 - 257ms/epoch - 16ms/step
# Epoch 42/150
# 16/16 - 0s - loss: 1.0308e-04 - val_loss: 5.4658e-05 - 269ms/epoch - 17ms/step
# Epoch 43/150
# 16/16 - 0s - loss: 1.4131e-04 - val_loss: 1.7774e-04 - 262ms/epoch - 16ms/step
# Epoch 44/150
# 16/16 - 0s - loss: 1.3996e-04 - val_loss: 3.0355e-04 - 383ms/epoch - 24ms/step
# Epoch 45/150
# 16/16 - 0s - loss: 1.6201e-04 - val_loss: 5.3517e-05 - 364ms/epoch - 23ms/step
# Epoch 46/150
# 16/16 - 0s - loss: 1.3959e-04 - val_loss: 3.4166e-05 - 367ms/epoch - 23ms/step

# %%
import datetime
from datetime import timedelta
# Persiapkan data input untuk prediksi 30 hari ke depan
n_steps = 121
last_data_points = scaled_data[-n_steps:]
future_steps = 30  # Prediksi 30 hari ke depan
future_data_lstm = []
future_data_gru = []

for i in range(future_steps):
    # Reshape data untuk sesuai dengan input model
    X_future = last_data_points[-n_steps:].reshape((1, n_steps, 1))

    # Lakukan prediksi menggunakan model LSTM
    predicted_price_lstm = final_model_lstm.predict(X_future)
    future_data_lstm.append(predicted_price_lstm)

    # Lakukan prediksi menggunakan model GRU
    predicted_price_gru = final_model_gru.predict(X_future)
    future_data_gru.append(predicted_price_gru)

    # Update data input untuk iterasi berikutnya
    last_data_points = np.append(last_data_points, predicted_price_lstm, axis=0)
    last_data_points = np.delete(last_data_points, 0, axis=0)

# Inverse transformasi untuk mendapatkan harga yang sebenarnya
future_data_lstm = np.array(future_data_lstm).reshape(-1, 1)
future_data_gru = np.array(future_data_gru).reshape(-1, 1)
predicted_prices_future_lstm = scaler.inverse_transform(future_data_lstm)
predicted_prices_future_gru = scaler.inverse_transform(future_data_gru)

# Hasil prediksi untuk 30 hari ke depan
print("Prediksi harga untuk 30 hari ke depan (LSTM):")
print(predicted_prices_future_lstm)

print("Prediksi harga untuk 30 hari ke depan (GRU):")
print(predicted_prices_future_gru)

start_date = data.index[-1].to_pydatetime()
dates = [start_date + timedelta(days=i) for i in range(1, future_steps+1)]

# Plot the predicted prices
plt.figure(figsize=(12, 6))
plt.plot(dates, predicted_prices_future_lstm, label='Prediksi LSTM', marker='o')
plt.plot(dates, predicted_prices_future_gru, label='Prediksi GRU', marker='o')
plt.title('Prediksi Harga untuk 30 Hari ke Depan')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Prediksi harga untuk 30 hari ke depan (LSTM):
# [[1.4498005 ]
#  [1.3740709 ]
#  [1.3097988 ]
#  [1.2521486 ]
#  [1.2015489 ]
#  [1.1550498 ]
#  [1.1109523 ]
#  [1.0687084 ]
#  [1.0284152 ]
#  [0.9903292 ]
#  [0.95462036]
#  [0.9213101 ]
#  [0.890302  ]
#  [0.86143243]
#  [0.8345128 ]
#  [0.8093557 ]
#  [0.78578645]
#  [0.7636479 ]
#  [0.74280113]
#  [0.72312325]
#  [0.704507  ]
#  [0.68685865]
#  [0.67009676]
#  [0.6541507 ]
#  [0.63895935]
#  [0.62446964]
#  [0.6106354 ]
#  [0.59741616]
#  [0.58477587]
#  [0.5726824 ]]
# Prediksi harga untuk 30 hari ke depan (GRU):
# [[1.4839236 ]
#  [1.4541075 ]
#  [1.378698  ]
#  [1.3114426 ]
#  [1.2552242 ]
#  [1.2067571 ]
#  [1.1622177 ]
#  [1.1194715 ]
#  [1.0779597 ]
#  [1.0379319 ]
#  [0.99981135]
#  [0.9638878 ]
#  [0.93025464]
#  [0.8988548 ]
#  [0.8695484 ]
#  [0.8421632 ]
#  [0.8165255 ]
#  [0.79247195]
#  [0.7698546 ]
#  [0.7485405 ]
#  [0.7284115 ]
#  [0.7093622 ]
#  [0.6912997 ]
#  [0.6741421 ]
#  [0.6578182 ]
#  [0.6422653 ]
#  [0.6274292 ]
#  [0.61326224]
#  [0.59972286]
#  [0.586774  ]]

# %% [markdown]
# #**Evaluasi Model dan Visualisasi**

# %%
# Model evaluation for LSTM
y_pred_lstm = final_model_lstm.predict(X_test_lstm)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm)
y_test_orig_lstm = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics for LSTM
mse_lstm = mean_squared_error(y_test_orig_lstm, y_pred_lstm)
rmse_lstm = math.sqrt(mse_lstm)
mape_lstm = np.mean(np.abs((y_test_orig_lstm - y_pred_lstm) / y_test_orig_lstm)) * 100
mad_lstm = mean_absolute_error(y_test_orig_lstm, y_pred_lstm)

# Display results for LSTM
print("Performance Metrics for LSTM:")
print("Mean Squared Error (MSE):", mse_lstm)
print("Root Mean Squared Error (RMSE):", rmse_lstm)
print("Mean Absolute Percentage Error (MAPE):", mape_lstm)
print("Mean Absolute Deviation (MAD):", mad_lstm)

# Model evaluation for GRU
y_pred_gru = final_model_gru.predict(X_test_gru)
y_pred_gru = scaler.inverse_transform(y_pred_gru)
y_test_orig_gru = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics for GRU
mse_gru = mean_squared_error(y_test_orig_gru, y_pred_gru)
rmse_gru = math.sqrt(mse_gru)
mape_gru = np.mean(np.abs((y_test_orig_gru - y_pred_gru) / y_test_orig_gru)) * 100
mad_gru = mean_absolute_error(y_test_orig_gru, y_pred_gru)

# Display results for GRU
print("Performance Metrics for GRU:")
print("Mean Squared Error (MSE):", mse_gru)
print("Root Mean Squared Error (RMSE):", rmse_gru)
print("Mean Absolute Percentage Error (MAPE):", mape_gru)
print("Mean Absolute Deviation (MAD):", mad_gru)

# Visualize predictions for the final LSTM model
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index[train_size + n_steps:],
                         y=y_test_orig_lstm.flatten(),
                         mode='lines',
                         name="Actual Stock Prices",
                         line=dict(color='blue')))

fig.add_trace(go.Scatter(x=data.index[train_size + n_steps:],
                         y=y_pred_lstm.flatten(),
                         mode='lines',
                         name="Predicted Stock Prices (LSTM)",
                         line=dict(color='red')))


# Visualize predictions for the final GRU model
fig.add_trace(go.Scatter(x=data.index[train_size + n_steps:],
                         y=y_pred_gru.flatten(),
                         mode='lines',
                         name="Predicted Stock Prices (GRU)",
                         line=dict(color='orange')))

# Plot the predicted prices for 30 days ahead
fig.add_trace(go.Scatter(x=dates,
                         y=predicted_prices_future_lstm.flatten(),
                         mode='lines',
                         name="Predicted Stock Prices for 30 Days (LSTM)",
                         line=dict(color='green')))

fig.add_trace(go.Scatter(x=dates,
                         y=predicted_prices_future_gru.flatten(),
                         mode='lines',
                         name="Predicted Stock Prices for 30 Days (GRU)",
                         line=dict(color='purple')))


fig.update_layout(title="Stock Price Prediction (LSTM vs GRU)",
                  xaxis_title="Date",
                  yaxis_title="Stock Price (IDR)",
                  template='plotly_dark')



fig.show()

# Plot training history using Matplotlib
plt.figure(figsize=(16, 8))

# Plot training loss for LSTM
plt.subplot(2, 1, 1)
plt.plot(history_lstm.history['loss'], label='Train Loss (LSTM)', color='blue')
plt.plot(history_lstm.history['val_loss'], label='Validation Loss (LSTM)', color='red')
plt.title('Training Loss for LSTM')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training loss for GRU
plt.subplot(2, 1, 2)
plt.plot(history_gru.history['loss'], label='Train Loss (GRU)', color='green')
plt.plot(history_gru.history['val_loss'], label='Validation Loss (GRU)', color='orange')
plt.title('Training Loss for GRU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 13ms/step
# Performance Metrics for LSTM:
# Mean Squared Error (MSE): 0.0007893254100914086
# Root Mean Squared Error (RMSE): 0.028094935666262144
# Mean Absolute Percentage Error (MAPE): 2.726439518990173
# Mean Absolute Deviation (MAD): 0.02186492842728973
# 4/4 [==============================] - 0s 12ms/step
# Performance Metrics for GRU:
# Mean Squared Error (MSE): 0.00015608392214990792
# Root Mean Squared Error (RMSE): 0.012493355119819012
# Mean Absolute Percentage Error (MAPE): 0.9985578499431014
# Mean Absolute Deviation (MAD): 0.007804362988862828
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="abf4b983-7887-472a-a40b-2e5176909f83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abf4b983-7887-472a-a40b-2e5176909f83")) {                    Plotly.newPlot(                        "abf4b983-7887-472a-a40b-2e5176909f83",                        [{"line":{"color":"blue"},"mode":"lines","name":"Actual Stock Prices","x":["2023-09-02T00:00:00","2023-09-03T00:00:00","2023-09-04T00:00:00","2023-09-05T00:00:00","2023-09-06T00:00:00","2023-09-07T00:00:00","2023-09-08T00:00:00","2023-09-09T00:00:00","2023-09-10T00:00:00","2023-09-11T00:00:00","2023-09-12T00:00:00","2023-09-13T00:00:00","2023-09-14T00:00:00","2023-09-15T00:00:00","2023-09-16T00:00:00","2023-09-17T00:00:00","2023-09-18T00:00:00","2023-09-19T00:00:00","2023-09-20T00:00:00","2023-09-21T00:00:00","2023-09-22T00:00:00","2023-09-23T00:00:00","2023-09-24T00:00:00","2023-09-25T00:00:00","2023-09-26T00:00:00","2023-09-27T00:00:00","2023-09-28T00:00:00","2023-09-29T00:00:00","2023-09-30T00:00:00","2023-10-01T00:00:00","2023-10-02T00:00:00","2023-10-03T00:00:00","2023-10-04T00:00:00","2023-10-05T00:00:00","2023-10-06T00:00:00","2023-10-07T00:00:00","2023-10-08T00:00:00","2023-10-09T00:00:00","2023-10-10T00:00:00","2023-10-11T00:00:00","2023-10-12T00:00:00","2023-10-13T00:00:00","2023-10-14T00:00:00","2023-10-15T00:00:00","2023-10-16T00:00:00","2023-10-17T00:00:00","2023-10-18T00:00:00","2023-10-19T00:00:00","2023-10-20T00:00:00","2023-10-21T00:00:00","2023-10-22T00:00:00","2023-10-23T00:00:00","2023-10-24T00:00:00","2023-10-25T00:00:00","2023-10-26T00:00:00","2023-10-27T00:00:00","2023-10-28T00:00:00","2023-10-29T00:00:00","2023-10-30T00:00:00","2023-10-31T00:00:00","2023-11-01T00:00:00","2023-11-02T00:00:00","2023-11-03T00:00:00","2023-11-04T00:00:00","2023-11-05T00:00:00","2023-11-06T00:00:00","2023-11-07T00:00:00","2023-11-08T00:00:00","2023-11-09T00:00:00","2023-11-10T00:00:00","2023-11-11T00:00:00","2023-11-12T00:00:00","2023-11-13T00:00:00","2023-11-14T00:00:00","2023-11-15T00:00:00","2023-11-16T00:00:00","2023-11-17T00:00:00","2023-11-18T00:00:00","2023-11-19T00:00:00","2023-11-20T00:00:00","2023-11-21T00:00:00","2023-11-22T00:00:00","2023-11-23T00:00:00","2023-11-24T00:00:00","2023-11-25T00:00:00","2023-11-26T00:00:00","2023-11-27T00:00:00","2023-11-28T00:00:00","2023-11-29T00:00:00","2023-11-30T00:00:00","2023-12-01T00:00:00","2023-12-02T00:00:00","2023-12-03T00:00:00","2023-12-04T00:00:00","2023-12-05T00:00:00","2023-12-06T00:00:00","2023-12-07T00:00:00","2023-12-08T00:00:00","2023-12-09T00:00:00","2023-12-10T00:00:00","2023-12-11T00:00:00","2023-12-12T00:00:00","2023-12-13T00:00:00","2023-12-14T00:00:00","2023-12-15T00:00:00","2023-12-16T00:00:00","2023-12-17T00:00:00","2023-12-18T00:00:00","2023-12-19T00:00:00","2023-12-20T00:00:00","2023-12-21T00:00:00","2023-12-22T00:00:00","2023-12-23T00:00:00","2023-12-24T00:00:00","2023-12-25T00:00:00","2023-12-26T00:00:00","2023-12-27T00:00:00","2023-12-28T00:00:00","2023-12-29T00:00:00","2023-12-30T00:00:00","2023-12-31T00:00:00"],"y":[0.46873900294303894,0.459293007850647,0.4557279944419861,0.4528779983520508,0.475151002407074,0.46477198600769043,0.4728670120239258,0.4630439877510071,0.46763598918914795,0.45062699913978577,0.427852988243103,0.44152700901031494,0.4595569968223572,0.4685179889202118,0.4688880145549774,0.4717490077018738,0.453559011220932,0.48213300108909607,0.49222901463508606,0.48868900537490845,0.471778005361557,0.471774011850357,0.472790002822876,0.4635089933872223,0.4643149971961975,0.45678800344467163,0.4582270085811615,0.4843359887599945,0.4773719906806946,0.4804779887199402,0.5119330286979675,0.5154579877853394,0.4889320135116577,0.4961180090904236,0.49514299631118774,0.517956018447876,0.517556 ...

# %%
# !pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 58.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.1.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.2

# %%
import streamlit as st
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adamax
from sklearn.metrics import mean_squared_error
import math
from hyperopt import fmin, tpe, hp, space_eval, Trials
from tensorflow.keras.callbacks import EarlyStopping
from pyngrok import ngrok
import plotly.graph_objects as go

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Streamlit app
def main():
    st.title("Stock Price Prediction App")

    # Download stock price data
    st.sidebar.header("Data Download")
    stock_symbol = st.sidebar.text_input("Enter Stock Symbol (e.g., BBCA.JK):", "BBCA.JK")
    start_date = st.sidebar.date_input("Start Date", pd.to_datetime("2021-01-01"))
    end_date = st.sidebar.date_input("End Date", pd.to_datetime("2023-01-01"))

    data = yf.download(stock_symbol, start=start_date, end=end_date)

    # Data preprocessing
    close_prices = data['Close'].values.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(close_prices)

    # Data preparation
    n_steps = st.sidebar.slider("Select Number of Time Steps:", min_value=10, max_value=300, value=120, step=10)
    X, y = prepare_data(scaled_data, n_steps)

    # Splitting into train and test sets
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Reshape data for LSTM and GRU models
    X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    X_train_gru = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test_gru = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Sidebar for hyperparameter tuning
    st.sidebar.header("Hyperparameter Tuning")
    units = st.sidebar.selectbox("Select Number of Units:", [50, 100, 150], index=1)
    dropout_rate = st.sidebar.slider("Select Dropout Rate:", min_value=0.2, max_value=0.5, value=0.4, step=0.01)
    learning_rate = st.sidebar.slider("Select Learning Rate:", np.log(0.001), np.log(0.01), value=np.log(0.005), step=0.001)
    epochs = st.sidebar.selectbox("Select Number of Epochs:", [50, 100, 150], index=1)
    batch_size = st.sidebar.selectbox("Select Batch Size:", [32, 64, 128], index=1)

    # Hyperparameter search space
    space = {
        'units': units,
        'dropout_rate': dropout_rate,
        'learning_rate': np.exp(learning_rate),
        'epochs': epochs,
        'batch_size': batch_size
    }

    # Define early stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Run hyperparameter optimization
    best_params_lstm, history_lstm, y_pred_lstm, y_test_orig_lstm = run_optimization(space, 'lstm', X_train_lstm, y_train, X_test_lstm, y_test, scaler, early_stopping)
    best_params_gru, history_gru, y_pred_gru, y_test_orig_gru = run_optimization(space, 'gru', X_train_gru, y_train, X_test_gru, y_test, scaler, early_stopping)

    # Display results
    st.header("Results for LSTM Model")
    display_results(best_params_lstm, history_lstm, y_test_orig_lstm, y_pred_lstm)

    st.header("Results for GRU Model")
    display_results(best_params_gru, history_gru, y_test_orig_gru, y_pred_gru)

    # Visualize predictions for the final LSTM model
    st.header("Visualize Predictions (LSTM)")
    visualize_predictions(data, train_size, n_steps, y_test_orig_lstm, y_pred_lstm)

    # Visualize predictions for the final GRU model
    st.header("Visualize Predictions (GRU)")
    visualize_predictions(data, train_size, n_steps, y_test_orig_gru, y_pred_gru)

    # Plot training history using Matplotlib
    st.header("Training History")
    plot_training_history(history_lstm, history_gru)


def prepare_data(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        lag_values = data[i:(i + n_steps), 0]
        X.append(np.concatenate([lag_values, [data[i + n_steps, 0]]]))
        y.append(data[i + n_steps, 0])
    return np.array(X), np.array(y)


def run_optimization(space, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping):
    # Set up the Trials object to keep track of the optimization process
    trials = Trials()

    # Use the fmin function for Bayesian optimization
    best_params = fmin(fn=lambda params: objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping),
                      space=space, algo=tpe.suggest, max_evals=20, trials=trials)

    # Get the best hyperparameters from the optimization results
    best_params = space_eval(space, best_params)

    # Build the final model using the best hyperparameters
    final_model = build_model(best_params, model_type, X_train)

    # Train the final model
    history = final_model.fit(X_train, y_train,
                              epochs=best_params['epochs'],
                              batch_size=best_params['batch_size'],
                              verbose=2,
                              validation_split=0.1,
                              callbacks=[early_stopping])

    # Model evaluation
    y_pred = final_model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred)
    y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

    return best_params, history, y_pred, y_test_orig


def build_model(params, model_type, X_train):
    model = Sequential()
    if model_type == 'lstm':
        model.add(LSTM(units=params['units'], return_sequences=True, activation='tanh', input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(params['dropout_rate']))
        model.add(LSTM(units=params['units'], return_sequences=True, activation='tanh'))
        model.add(Dropout(params['dropout_rate']))
        model.add(LSTM(units=params['units'], activation='tanh'))
        model.add(Dense(units=1))
    elif model_type == 'gru':
        model.add(GRU(units=params['units'], return_sequences=True, activation='tanh', input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(params['dropout_rate']))
        model.add(GRU(units=params['units'], return_sequences=True, activation='tanh'))
        model.add(Dropout(params['dropout_rate']))
        model.add(GRU(units=params['units'], activation='tanh'))
        model.add(Dense(units=1))

    model.compile(optimizer=Adamax(learning_rate=params['learning_rate']), loss='mean_squared_error')
    return model


def objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping):
    # Build and train the model
    final_model = build_model(params, model_type, X_train)
    history = final_model.fit(X_train, y_train,
                              epochs=params['epochs'],
                              batch_size=params['batch_size'],
                              verbose=0,
                              validation_split=0.1,
                              callbacks=[early_stopping])

    # Model evaluation
    y_pred = final_model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred)
    y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

    # Calculate and return mean squared error
    mse = mean_squared_error(y_test_orig, y_pred)
    return mse


def display_results(best_params, history, y_test_orig, y_pred):
    mse = mean_squared_error(y_test_orig, y_pred)
    rmse = math.sqrt(mse)
    mape = np.mean(np.abs((y_test_orig - y_pred) / y_test_orig)) * 100

    st.write("Best Hyperparameters:", best_params)
    st.write("Mean Squared Error (MSE):", mse)
    st.write("Root Mean Squared Error (RMSE):", rmse)
    st.write("Mean Absolute Percentage Error (MAPE):", mape)

    # Plot training loss
    st.line_chart(pd.DataFrame({'Train Loss': history.history['loss'], 'Validation Loss': history.history['val_loss']}))


def visualize_predictions(data, train_size, n_steps, y_test_orig, y_pred):
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=data.index[train_size + n_steps:],
                             y=y_test_orig.flatten(),
                             mode='lines',
                             name="Actual Stock Prices",
                             line=dict(color='blue')))

    fig.add_trace(go.Scatter(x=data.index[train_size + n_steps:],
                             y=y_pred.flatten(),
                             mode='lines',
                             name="Predicted Stock Prices",
                             line=dict(color='red')))

    fig.update_layout(title="Stock Price Prediction",
                      xaxis_title="Date",
                      yaxis_title="Stock Price (IDR)",
                      template='plotly_dark')

    st.plotly_chart(fig)


def plot_training_history(history_lstm, history_gru):
    plt.figure(figsize=(16, 8))

    # Plot training loss for LSTM
    plt.subplot(2, 1, 1)
    plt.plot(history_lstm.history['loss'], label='Train Loss (LSTM)', color='blue')
    plt.plot(history_lstm.history['val_loss'], label='Validation Loss (LSTM)', color='red')
    plt.title('Training Loss for LSTM')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training loss for GRU
    plt.subplot(2, 1, 2)
    plt.plot(history_gru.history['loss'], label='Train Loss (GRU)', color='green')
    plt.plot(history_gru.history['val_loss'], label='Validation Loss (GRU)', color='orange')
    plt.title('Training Loss for GRU')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    st.pyplot()

if __name__ == "__main__":
    main()
# Out:
# 2024-02-15 05:34:05.236
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# [*********************100%%**********************]  1 of 1 completed
#   0%|          | 0/20 [00:00<?, ?trial/s, best loss=?]
# 1/3 [=========>....................] - ETA: 1s
# 3/3 [==============================] - 1s 12ms/step
#
# 1/3 [=========>....................] - ETA: 1s
# 3/3 [==============================] - 1s 12ms/step
#
#  10%|█         | 2/20 [00:26<03:54, 13.01s/trial, best loss: 52719.33059106191]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-44ba09667420> in <cell line: 239>()
#     238
#     239 if __name__ == "__main__":
# --> 240     main()
#
# <ipython-input-8-44ba09667420> in main()
#      73
#      74     # Run hyperparameter optimization
# ---> 75     best_params_lstm, history_lstm, y_pred_lstm, y_test_orig_lstm = run_optimization(space, 'lstm', X_train_lstm, y_train, X_test_lstm, y_test, scaler, early_stopping)
#      76     best_params_gru, history_gru, y_pred_gru, y_test_orig_gru = run_optimization(space, 'gru', X_train_gru, y_train, X_test_gru, y_test, scaler, early_stopping)
#      77
#
# <ipython-input-8-44ba09667420> in run_optimization(space, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping)
#     110
#     111     # Use the fmin function for Bayesian optimization
# --> 112     best_params = fmin(fn=lambda params: objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping),
#     113                       space=space, algo=tpe.suggest, max_evals=20, trials=trials)
#     114
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-8-44ba09667420> in <lambda>(params)
#     110
#     111     # Use the fmin function for Bayesian optimization
# --> 112     best_params = fmin(fn=lambda params: objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping),
#     113                       space=space, algo=tpe.suggest, max_evals=20, trials=trials)
#     114
#
# <ipython-input-8-44ba09667420> in objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping)
#     158 def objective(params, model_type, X_train, y_train, X_test, y_test, scaler, early_stopping):
#     159     # Build and train the model
# --> 160     final_model = build_model(params, model_type, X_train)
#     161     history = final_model.fit(X_train, y_train,
#     162                               epochs=params['epochs'],
#
# <ipython-input-8-44ba09667420> in build_model(params, model_type, X_train)
#     142         model.add(LSTM(units=params['units'], return_sequences=True, activation='tanh'))
#     143         model.add(Dropout(params['dropout_rate']))
# --> 144         model.add(LSTM(units=params['units'], activation='tanh'))
#     145         model.add(Dense(units=1))
#     146     elif model_type == 'gru':
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/sequential.py in add(self, layer)
#     227             # If the model is being built continuously on top of an input layer:
#     228             # refresh its output.
# --> 229             output_tensor = layer(self.outputs[0])
#     230             if len(tf.nest.flatten(output_tensor)) != 1:
#     231                 raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/base_rnn.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     554
#     555         if initial_state is None and constants is None:
# --> 556             return super().__call__(inputs, **kwargs)
#     557
#     558         # If any of `initial_state` or `constants` are specified and are Keras
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1061             self, inputs, args, kwargs, input_list
#    1062         ):
# -> 1063             return self._functional_construction_call(
#    1064                 inputs, args, kwargs, input_list
#    1065             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    2591             # shape.
#    2592             try:
# -> 2593                 outputs = self._keras_tensor_symbolic_call(
#    2594                     inputs, input_masks, args, kwargs
#    2595                 )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2437             )
#    2438         else:
# -> 2439             return self._infer_output_signature(
#    2440                 inputs, args, kwargs, input_masks
#    2441             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2494                     # TODO(kaftan): do we maybe_build here, or have we already
#    2495                     # done it?
# -> 2496                     self._maybe_build(inputs)
#    2497                     inputs = self._maybe_cast_inputs(inputs)
#    2498                     outputs = call_fn(inputs, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _maybe_build(self, inputs)
#    3025                 # later pollute any eager operations.
#    3026                 with tf_utils.maybe_init_scope(self):
# -> 3027                     self.build(input_shapes)
#    3028             # We must set also ensure that the layer is marked as built, and the
#    3029             # build shape is stored since user defined build functions may not
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/base_rnn.py in build(self, input_shape)
#     459         if isinstance(self.cell, base_layer.Layer) and not self.cell.built:
#     460             with backend.name_scope(self.cell.name):
# --> 461                 self.cell.build(step_input_shape)
#     462                 self.cell.built = True
#     463
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in wrapper(instance, input_shape)
#     369         if input_shape is not None:
#     370             input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 371         output_shape = fn(instance, input_shape)
#     372         # Return shapes from `fn` as TensorShapes.
#     373         if output_shape is not None:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py in build(self, input_shape)
#     189         default_caching_device = rnn_utils.caching_device(self)
#     190         input_dim = input_shape[-1]
# --> 191         self.kernel = self.add_weight(
#     192             shape=(input_dim, self.units * 4),
#     193             name="kernel",
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __setattr__(self, name, value)
#    3211
#    3212         # Keep track of metric instance created in subclassed layer.
# -> 3213         for val in tf.nest.flatten(value):
#    3214             if isinstance(val, metrics_mod.Metric) and hasattr(
#    3215                 self, "_metrics"
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in flatten(structure, expand_composites)
#     199
#     200
# --> 201 @tf_export("nest.flatten")
#     202 def flatten(structure, expand_composites=False):
#     203   """Returns a flat list from a given structure.
#
# KeyboardInterrupt:

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.476s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run app.py &>/dev/null&

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.91.185.94

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.644s
# your url is: https://four-oranges-grab.loca.lt
# /root/.npm/_npx/101898/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:43929 (check your firewall settings)
#     at Socket.<anonymous> (/root/.npm/_npx/101898/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)

# %%
# !streamlit run app.py --server.address=localhost &>/content/logs.txt &

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.91.185.94

# %%
from google.colab import files

# Save the final LSTM model
final_model_lstm.save("final_model_lstm.h5")

# Download the saved LSTM model
files.download("final_model_lstm.h5")

# Save the final GRU model
final_model_gru.save("final_model_gru.h5")

# Download the saved GRU model
files.download("final_model_gru.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
